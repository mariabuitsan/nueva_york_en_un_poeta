# %% [markdown]
# ## Text-Analysis Project
# #### Poeta en Nueva York – María Buitrago
# #### Analyzing the use, context and references to animal's in the text

# %%
import nltk
from nltk.corpus import stopwords 
from nltk.stem import WordNetLemmatizer

# %%
#creating a variable to locate my txt file 

text_FGL = ('Poeta_en_Nueva_York.txt')

# %%
#reading the lines

project = open (text_FGL)
text_lorca = project.readlines()

# %%
print(text_lorca)
# Out:
# ['POEMAS DE LA SOLEDAD EN COLUMBIA UNIVERSITY\n', 'VUELTA DE PASEO\n', 'Asesinado por el cielo,\n', 'entre las formas que van hacia la sierpe\n', 'y las formas que buscan el cristal,\n', 'dejaré crecer mis cabellos.\n', 'Con el árbol de muñones que no canta\n', 'y el niño con el blanco rostro de huevo.\n', 'Con los animalitos de cabeza rota\n', 'y el agua harapienta de los pies secos.\n', 'Con todo lo que tiene cansancio sordomudo\n', 'y mariposa ahogada en el tintero.\n', 'Tropezando con mi rostro distinto de cada día.\n', '¡Asesinado por el cielo!\n', '1910\n', '(INTERMEDIO)\n', 'Aquellos ojos míos de mil novecientos diez\n', 'no vieron enterrar a los muertos,\n', 'ni la feria de ceniza del que llora por la madrugada,\n', 'ni el corazón que tiembla arrinconado como un caba-\n', 'llito de mar.\n', 'Aquellos ojos míos de mil novecientos diez\n', 'vieron la blanca pared donde orinaban las niñas,\n', 'el hocico del toro, la seta venenosa\n', 'y una luna incomprensible que iluminaba por
# ...

# %%
#removing linebreaks

modified_lorca =[]

for line in text_lorca:
    if line [-1] == '\n':
        modified_lorca.append(line[:-1])                  
    else:
        modified_lorca.append(line)

# %%
print(modified_lorca)
# Out:
# ['POEMAS DE LA SOLEDAD EN COLUMBIA UNIVERSITY', 'VUELTA DE PASEO', 'Asesinado por el cielo,', 'entre las formas que van hacia la sierpe', 'y las formas que buscan el cristal,', 'dejaré crecer mis cabellos.', 'Con el árbol de muñones que no canta', 'y el niño con el blanco rostro de huevo.', 'Con los animalitos de cabeza rota', 'y el agua harapienta de los pies secos.', 'Con todo lo que tiene cansancio sordomudo', 'y mariposa ahogada en el tintero.', 'Tropezando con mi rostro distinto de cada día.', '¡Asesinado por el cielo!', '1910', '(INTERMEDIO)', 'Aquellos ojos míos de mil novecientos diez', 'no vieron enterrar a los muertos,', 'ni la feria de ceniza del que llora por la madrugada,', 'ni el corazón que tiembla arrinconado como un caba-', 'llito de mar.', 'Aquellos ojos míos de mil novecientos diez', 'vieron la blanca pared donde orinaban las niñas,', 'el hocico del toro, la seta venenosa', 'y una luna incomprensible que iluminaba por los', 'rincones', 'los pedazos de limón seco ba
# ...

# %%
type(modified_lorca)
# Out:
# list

# %%
list1 = []

for line in modified_lorca:
    line_split = line.split()
    list1.append(line_split)

# %%
#Now I have a list of lines
print(list1)
# Out:
# [['POEMAS', 'DE', 'LA', 'SOLEDAD', 'EN', 'COLUMBIA', 'UNIVERSITY'], ['VUELTA', 'DE', 'PASEO'], ['Asesinado', 'por', 'el', 'cielo,'], ['entre', 'las', 'formas', 'que', 'van', 'hacia', 'la', 'sierpe'], ['y', 'las', 'formas', 'que', 'buscan', 'el', 'cristal,'], ['dejaré', 'crecer', 'mis', 'cabellos.'], ['Con', 'el', 'árbol', 'de', 'muñones', 'que', 'no', 'canta'], ['y', 'el', 'niño', 'con', 'el', 'blanco', 'rostro', 'de', 'huevo.'], ['Con', 'los', 'animalitos', 'de', 'cabeza', 'rota'], ['y', 'el', 'agua', 'harapienta', 'de', 'los', 'pies', 'secos.'], ['Con', 'todo', 'lo', 'que', 'tiene', 'cansancio', 'sordomudo'], ['y', 'mariposa', 'ahogada', 'en', 'el', 'tintero.'], ['Tropezando', 'con', 'mi', 'rostro', 'distinto', 'de', 'cada', 'día.'], ['¡Asesinado', 'por', 'el', 'cielo!'], ['1910'], ['(INTERMEDIO)'], ['Aquellos', 'ojos', 'míos', 'de', 'mil', 'novecientos', 'diez'], ['no', 'vieron', 'enterrar', 'a', 'los', 'muertos,'], ['ni', 'la', 'feria', 'de', 'ceniza', 'del', 'que', 'llora', 'por
# ...

# %%
list1.remove([] )
list1.remove( [])

# %%
print(list1)
# Out:
# [['POEMAS', 'DE', 'LA', 'SOLEDAD', 'EN', 'COLUMBIA', 'UNIVERSITY'], ['VUELTA', 'DE', 'PASEO'], ['Asesinado', 'por', 'el', 'cielo,'], ['entre', 'las', 'formas', 'que', 'van', 'hacia', 'la', 'sierpe'], ['y', 'las', 'formas', 'que', 'buscan', 'el', 'cristal,'], ['dejaré', 'crecer', 'mis', 'cabellos.'], ['Con', 'el', 'árbol', 'de', 'muñones', 'que', 'no', 'canta'], ['y', 'el', 'niño', 'con', 'el', 'blanco', 'rostro', 'de', 'huevo.'], ['Con', 'los', 'animalitos', 'de', 'cabeza', 'rota'], ['y', 'el', 'agua', 'harapienta', 'de', 'los', 'pies', 'secos.'], ['Con', 'todo', 'lo', 'que', 'tiene', 'cansancio', 'sordomudo'], ['y', 'mariposa', 'ahogada', 'en', 'el', 'tintero.'], ['Tropezando', 'con', 'mi', 'rostro', 'distinto', 'de', 'cada', 'día.'], ['¡Asesinado', 'por', 'el', 'cielo!'], ['1910'], ['(INTERMEDIO)'], ['Aquellos', 'ojos', 'míos', 'de', 'mil', 'novecientos', 'diez'], ['no', 'vieron', 'enterrar', 'a', 'los', 'muertos,'], ['ni', 'la', 'feria', 'de', 'ceniza', 'del', 'que', 'llora', 'por
# ...

# %%
#saving the list as a nltk object
first_try = nltk.text(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/f9/xvsz9xjx3x71q6sk340qg0ch0000gn/T/ipykernel_12607/983738073.py in <module>
#       1 #saving the list as a nltk object
# ----> 2 first_try = nltk.text(list1)
#
# TypeError: 'module' object is not callable

# %%
len(list1)

# %%
lorca_words =[]

for item in list1:
    if item.isalpha():
        lorca_words.append(item)

# %%
modified_lorca.similar('caballo')

# %%
cleaned_lorca = []

for item in modified_lorca:
    if item.isalpha():
        cleaned_lorca.append(item)

# %%
print(cleaned_lorca)

# %%
def clean(text):
    stops = stopwords.words('spanish')
    wordnet_lemmatizer = WordNetLemmatizer()
    
    read_text = open.read()
    decoded_text = reading_lorca.decode()
    tokens = nltk.word_tokenize(decoded_text)
    
    text = [] 
    for word in tokens:
        if word.isalpha(): 
            if word not in stops:
                lemma = wordnet_lemmatizer.lemmatize(word)
                text.append(word.lower())     
    
    return text

# %%
clean(first_try)

# %%
print (modified_lorca)

# %%
clean(reading_lorca)

# %%
print(modified_lorca)

# %%
#cleaning empty space
list1 = []

for item in modified_lorca:
    item_cleaning = item.strip((" "))
    item
    list1.append(item_cleaning)
